# %%
x = 1
y = 1.1
z = "him"
print(x)
print(y)
print(z)
# Out:
# 1
# 1.1
# him

# %% [markdown]
# # I made 3 variables that are x, y, and z. x is an integer, y is a float, z is a string
# # I used the print command to print them

# %%
jar1 = 5
jar2 = 10
hello = "hello"
print (jar1 + jar2 + hello)

# %%
jar1 = 5
jar2 = 10
print (jar2)
jar2 = jar1
print (jar2)

# %%
name = "John"
age = 8
print ("My name is ", name , " and I am ", age, " years old!")
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          # when

# %% [markdown]
# # when i am printing multiplte things such as string litelrals and cariables all at onece, i separate netween them in the print statement with commas

# %%
first_name = "Blake"
last_name = "Hayama"
full_name = f" {first_name} {last_name}"

print (full_name)
print (f"Hello, {full_name.title()}!")
# Out:
#  Blake Hayama
# Hello,  Blake Hayama!

# %% [markdown]
# To combine two strings, you can put an f before the quotations and inside the quotes, put the name of it inside the squibly braces
