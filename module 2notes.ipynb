# %%
birthday= [ "febuary", "18", "2010"]
bday_as_string = f"I was born in the year {birthday[2]} on the day {birthday[1]} of the month {birthday[0]}."
print(bday_as_string)
# Out:
# I was born in the year 2010 on the day 18 of the month febuary.

# %%
siblings= ["jake", "lake", "drake"]
siblings_as_string = f"My favorite sibiling is {siblings[0]}, my second favorite is {siblings[1]}, and my least favorite sibling is {siblings[2]}."
print(siblings_as_string)
siblings[0]= "him"
siblings.append("Johnny")
print(siblings)
# Out:
# My favorite sibiling is jake, my second favorite is lake, and my least favorite sibling is drake.
# ['him', 'lake', 'drake', 'Johnny']

# %%
elements = ["hydrogen", "helium", "lithium", "beryllium", "iron", "aluminum", "boron", "carbon",]
print (elements) 
elements.sort()
elements.reverse()
print(elements)

flowers = ["rose", "lily", "daisy", "tulip", "sunflower"]
print(sorted(flowers))
print (flowers)

print("rose" in flowers)
print ("violet" in flowers)
# Out:
# ['hydrogen', 'helium', 'lithium', 'beryllium', 'iron', 'aluminum', 'boron', 'carbon']
# ['lithium', 'iron', 'hydrogen', 'helium', 'carbon', 'boron', 'beryllium', 'aluminum']
# ['daisy', 'lily', 'rose', 'sunflower', 'tulip']
# ['rose', 'lily', 'daisy', 'tulip', 'sunflower']

# %%
books= ["Harry Potter", "To Kill a Mockingbird", "1984", "Pride and Prejudice", ]
books[0]= "Harry Potter"
books[1]= "To Kill a Mockingbird"
books[2]= "1984"
books[3]= "Pride and Prejudice"

print(books)
# Out:
# ['Harry Potter', 'To Kill a Mockingbird', '1984', 'Pride and Prejudice']

# %%
teams = ["Bills", "Patriots", "Jets", "Dolphins"]
print(teams)
print(teams[0])
print(teams[1])
for thing in teams:
    print(thing)
    print("hello")
    print("Blake")
    print("loyola")
# Out:
# ['Bills', 'Patriots', 'Jets', 'Dolphins']
# Bills
# Patriots
# Bills
# hello
# Blake
# loyola
# Patriots
# hello
# Blake
# loyola
# Jets
# hello
# Blake
# loyola
# Dolphins
# hello
# Blake
# loyola

# %% [markdown]
# ### .sort() is a method that will change the order of the lsit to be in alphabetical order .reverse() reverses the order of a list. Both of these fundamentally change the order of the list permanently. On the other hand, sorted() is a function that can temporarily sort a list without permanently changing it.

# %%
grades= [100, 90, 80, 70, 60]
grades.insert(2, 100)
print((grades[0]+grades[1]+grades[2]+grades[3]+grades[4])/5)
# Out:
# 88.0

# %% [markdown]
# ### I can change the value of an item in the list by resetting it. for example my_list[1]= "new value". I can also use mthods on lists. some methods I can use are. append() and .insert(). Append adds an item to the end of the list. instert adds an item somwhere in the list and shifts everything down to the right. Append takes on parameter which means i put one value in () and that value is the thing I'm adding to the list.
